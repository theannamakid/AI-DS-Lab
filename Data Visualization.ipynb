# %%
import matplotlib.pyplot as plt
x=[4,6,2,8,5]
y=[7,9,1,4,0]
plt.plot(x,y)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("graph")
plt.show()

# %%
plt.stem(x,y)
plt.title('Stem Graph')
plt.show()
# Out:
# Text(0.5,1,'Stem Graph')

# %%
plt.bar(x,y)
plt.title("Bar graph")
plt.show()
# Out:
# Text(0.5,1,'Bar graph')
